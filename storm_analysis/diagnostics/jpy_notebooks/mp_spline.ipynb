# %% [markdown]
# ## Diagnostics for multi-plane with the spline PSF model

# %% [markdown]
# ### Configure environment

# %%
import os
os.chdir("/home/hbabcock/Data/storm_analysis/sa_diagnostics/mp_spline")
print(os.getcwd())
# Out:
# /home/hbabcock/Data/storm_analysis/sa_diagnostics/mp_spline

# %%
import storm_analysis.diagnostics.multiplane.settings as settings
import storm_analysis.diagnostics.multiplane.configure as configure
import storm_analysis.diagnostics.multiplane.make_data as makeData
import storm_analysis.diagnostics.multiplane.analyze_data as analyzeData
import storm_analysis.diagnostics.multiplane.collate as collate
# Out:
# /home/hbabcock/jupyter/jupyter/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
settings.photons = [[10, 500], [10, 1000]]
print(settings.photons)
# Out:
# [[10, 500], [10, 1000]]

# %% [markdown]
# ### Configure

# %%
configure.configure("spline", False)
# Out:
# Creating XML file.
# Creating gridded localization.
# Creating random localization.
# Creating data for PSF measurement.
# Added 18
# Added 18
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Measuring PSFs.
# Measuring Spline.
# Calculating weights.

# %% [markdown]
# ### Make Data

# %%
makeData.makeData()
# Out:
# Added 126
# Added 126
# test_01
# Frame 0 126 emitters
# Frame 1 126 emitters
# Frame 2 126 emitters
# Frame 3 126 emitters
# Frame 4 126 emitters
# Frame 5 126 emitters
# Frame 6 126 emitters
# Frame 7 126 emitters
# Frame 8 126 emitters
# Frame 9 126 emitters
# Frame 0 126 emitters
# Frame 1 126 emitters
# Frame 2 126 emitters
# Frame 3 126 emitters
# Frame 4 126 emitters
# Frame 5 126 emitters
# Frame 6 126 emitters
# Frame 7 126 emitters
# Frame 8 126 emitters
# Frame 9 126 emitters
# test_02
# Frame 0 126 emitters
# Frame 1 126 emitters
# Frame 2 126 emitters
# Frame 3 126 emitters
# Frame 4 126 emitters
# Frame 5 126 emitters
# Frame 6 126 emitters
# Frame 7 126 emitters
# Frame 8 126 emitters
# Frame 9 126 emitters
# Frame 0 126 emitters
# Frame 1 126 emitters
# Frame 2 126 emitters
# Frame 3 126 emitters
# Frame 4 126 emitters
# Frame 5 126 emitters
# Frame 6 126 emitters
# Frame 7 126 emitters
# Frame 8 126 emitters
# Frame 9 126 emitters

# %% [markdown]
# ### Analyze data

# %%
# %time analyzeData.analyzeData()
# Out:
# Analyzing: test_01
#
# weights z scaling - offset: 0.000 scale: 1.000
# Found data for 2 planes.
#
# Peak finding
# Frame: 0 126 126
# Frame: 1 125 251
# Frame: 2 125 376
# Frame: 3 125 501
# Frame: 4 126 627
# Frame: 5 126 753
# Frame: 6 125 878
# Frame: 7 125 1003
# Frame: 8 125 1128
# Frame: 9 126 1254
#
# Added 1254
#    50 peak finding iterations.
#
#
# Channel 0
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    0 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    4837 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#
# Channel 1
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    0 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    4837 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#
#    0 peaks lost to proximity.
#    0 peaks lost to low significance.
#    50168 fitting iterations.
#    25084.0 fitting iterations/channel.
#
# Tracking.
#
# Checking z values.
#  frame 0
#
# Analysis complete
# Analysis completed in 22.87 seconds
#
# Analyzing: test_02
#
# weights z scaling - offset: 0.000 scale: 1.000
# Found data for 2 planes.
#
# Peak finding
# Frame: 0 126 126
# Frame: 1 126 252
# Frame: 2 126 378
# Frame: 3 126 504
# Frame: 4 126 630
# Frame: 5 126 756
# Frame: 6 126 882
# Frame: 7 126 1008
# Frame: 8 126 1134
# Frame: 9 126 1260
#
# Added 1260
#    50 peak finding iterations.
#
#
# Channel 0
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    0 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    5672 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#
# Channel 1
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    0 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    5672 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#
#    0 peaks lost to proximity.
#    0 peaks lost to low significance.
#    60320 fitting iterations.
#    30160.0 fitting iterations/channel.
#
# Tracking.
#
# Checking z values.
#  frame 0
#
# Analysis complete
# Analysis completed in 25.97 seconds
# CPU times: user 48.4 s, sys: 451 ms, total: 48.9 s
# Wall time: 48.8 s

# %% [markdown]
# ### Collate data

# %%
collate.collate()
# Out:
# Added 1260
# Added 1260
# Processing test_01
# Using max_distance 200.0 nm for error calcuations.
# Processing test_02
# Using max_distance 200.0 nm for error calcuations.
#
# Analysis Summary:
# Processed 2514 localizations in 48.84 seconds, 51.47/sec
# Recall 0.62976
# Noise 0.37024
# XYZ Precision (nm):
# test_01	30.37	30.08	51.92
# test_02	15.79	15.99	30.31
#
# XYZ RMS Accuracy (nm):
# test_01	30.38	30.11	51.97
# test_02	15.79	15.99	30.31

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-03-21
# commit 87272d78c9bcb76e243f923fae702e6887e6a708
#
# Added 1260
# Added 1260
# Processing test_01
# Using max_distance 200.0 nm for error calcuations.
# Processing test_02
# Using max_distance 200.0 nm for error calcuations.
#
# Analysis Summary:
# Processed 2514 localizations in 48.84 seconds, 51.47/sec
# Recall 0.62976
# Noise 0.37024
# XYZ Precision (nm):
# test_01	30.37	30.08	51.92
# test_02	15.79	15.99	30.31
#
# XYZ RMS Accuracy (nm):
# test_01	30.38	30.11	51.97
# test_02	15.79	15.99	30.31
