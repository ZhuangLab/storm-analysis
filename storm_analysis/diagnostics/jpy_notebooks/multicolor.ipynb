# %% [markdown]
# ## Diagnostics for multi-color with the spline PSF model

# %% [markdown]
# ### Configure environment

# %%
import os
os.chdir("/home/hbabcock/Data/storm_analysis/sa_diagnostics/multicolor")
print(os.getcwd())
# Out:
# /home/hbabcock/Data/storm_analysis/sa_diagnostics/multicolor

# %%
import storm_analysis.diagnostics.multicolor.settings as settings
import storm_analysis.diagnostics.multicolor.configure as configure
import storm_analysis.diagnostics.multicolor.make_data as makeData
import storm_analysis.diagnostics.multicolor.analyze_data as analyzeData
import storm_analysis.diagnostics.multicolor.collate as collate
# Out:
# /home/hbabcock/pyenv/jupyter/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
settings.photons = [[10, 4000]]
print(settings.photons)
# Out:
# [[10, 4000]]

# %% [markdown]
# ### Configure
#
# This will take a while due to all the splines that need to be calculated

# %%
configure.configure()
# Out:
# Creating XML files.
# Creating gridded localizations.
# Creating random localizations.
# Creating random localizations.
# Creating data for PSF measurement.
# Measuring mapping.
# Added 18
# Added 18
# Added 18
# Added 18
# Added 18
# Added 18
# Added 18
# Added 18
# Frame 0 18 emitters
# Frame 0 18 emitters
# Frame 0 18 emitters
# Frame 0 18 emitters
#
# Peak finding
#  Removing values < 1.0 in frame 0
# Frame: 0 18 18
#
# Added 18
#    5 peak finding iterations.
#
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    17 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    7 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#    1 peaks lost to proximity filter.
#    0 peaks lost to low significance.
#    0 peaks lost to width filter.
#    760 fitting iterations.
#
# Tracking.
#
# Checking z values.
#
# Analysis complete
#
# Peak finding
#  Removing values < 1.0 in frame 0
# Frame: 0 18 18
#
# Added 18
#    5 peak finding iterations.
#
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    16 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    16 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#    1 peaks lost to proximity filter.
#    0 peaks lost to low significance.
#    0 peaks lost to width filter.
#    345 fitting iterations.
#
# Tracking.
#
# Checking z values.
#
# Analysis complete
#
# Peak finding
#  Removing values < 1.0 in frame 0
# Frame: 0 17 17
#
# Added 17
#    5 peak finding iterations.
#
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    16 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    9 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#    1 peaks lost to proximity filter.
#    0 peaks lost to low significance.
#    0 peaks lost to width filter.
#    548 fitting iterations.
#
# Tracking.
#
# Checking z values.
#
# Analysis complete
#
# Peak finding
#  Removing values < 1.0 in frame 0
# Frame: 0 17 17
#
# Added 17
#    5 peak finding iterations.
#
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    16 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    0 fits reset due to negative width.
#    20 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#    1 peaks lost to proximity filter.
#    0 peaks lost to low significance.
#    0 peaks lost to width filter.
#    3323 fitting iterations.
#
# Tracking.
#
# Checking z values.
#
# Analysis complete
# Mapping is:
#
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Frame 151 18 emitters
# Frame 152 18 emitters
# Frame 153 18 emitters
# Frame 154 18 emitters
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Frame 151 18 emitters
# Frame 152 18 emitters
# Frame 153 18 emitters
# Frame 154 18 emitters
# Measuring Splines.

# %% [markdown]
# ### Make Data

# %%
makeData.makeData()

# %% [markdown]
# ### Analyze data

# %%
# %time analyzeData.analyzeData()

# %% [markdown]
# ### Collate data

# %%
collate.collate()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-04-11
# commit 0ade57f031670efabc426a3582fc1b43754971e0
#
# Color 0, matching fraction is 1.00, unmatched fraction is 0.00, total 31
# Color 1, matching fraction is 1.00, unmatched fraction is 0.00, total 26
# Color 2, matching fraction is 1.00, unmatched fraction is 0.00, total 20
# Color 3, matching fraction is 1.00, unmatched fraction is 0.00, total 24
