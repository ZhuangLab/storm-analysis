# %% [markdown]
# ## Diagnostics for Cramer-Rao bounds calculations

# %% [markdown]
# ### Configure environment

# %%
import os
os.chdir("/home/hbabcock/Data/storm_analysis/sa_diagnostics/cramer_rao")
print(os.getcwd())

import numpy
numpy.random.seed(1)

# %%
import storm_analysis.diagnostics.cramer_rao.settings as settings
import storm_analysis.diagnostics.cramer_rao.configure as configure
import storm_analysis.diagnostics.cramer_rao.cr_test as crTest
import storm_analysis.diagnostics.cramer_rao.psf_test as psfTest

# %% [markdown]
# ### Configure

# %%
configure.configure()

# %% [markdown]
# ### Cramer-Rao test

# %%
crTest.crTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2019-10-30
# commit 84f60bd3a7568c26e44aef9222b9f3492568caa1
#
# No normalization data found, using 1.0.
# No normalization data found, using 1.0.
# No normalization data found, using 1.0.
# -0.500
# 127.0 30.34 30.01 24.28 0.2006
# 87.7 21.24 23.80 12.42 0.1734
# 149.3 34.09 34.21 27.89 0.2202
#
# -0.450
# 123.0 32.02 24.59 26.32 0.1973
# 98.8 25.50 20.91 21.54 0.1776
# 142.8 35.44 27.47 29.44 0.2148
#
# -0.400
# 116.4 32.91 20.14 28.70 0.1917
# 98.7 26.57 17.70 25.59 0.1780
# 134.1 35.85 22.08 31.53 0.2078
#
# -0.350
# 108.0 32.54 17.06 30.72 0.1863
# 87.7 27.13 15.37 24.49 0.1716
# 122.5 34.85 18.36 33.43 0.1988
#
# -0.300
# 98.5 30.47 14.98 32.75 0.1802
# 78.8 27.17 13.79 22.39 0.1671
# 108.4 32.27 15.90 34.47 0.1884
#
# -0.250
# 86.4 27.22 13.65 32.21 0.1728
# 76.7 25.08 12.71 28.20 0.1660
# 93.3 28.58 14.36 34.32 0.1782
#
# -0.200
# 73.7 23.63 12.89 31.61 0.1657
# 66.6 22.34 12.18 25.80 0.1618
# 79.8 24.63 13.47 33.22 0.1698
#
# -0.150
# 66.0 20.38 12.68 30.73 0.1619
# 62.1 19.47 12.02 26.86 0.1598
# 69.5 21.11 13.10 31.73 0.1642
#
# -0.100
# 61.0 17.71 12.78 29.39 0.1599
# 57.9 17.07 12.16 25.88 0.1581
# 62.8 18.29 13.18 30.37 0.1608
#
# -0.050
# 57.1 15.68 13.27 28.33 0.1582
# 55.0 15.19 12.62 25.34 0.1571
# 59.2 16.17 13.69 29.47 0.1591
#
# -0.000
# 56.6 14.27 14.29 28.28 0.1579
# 54.2 13.76 13.54 22.41 0.1569
# 58.1 14.66 14.66 29.15 0.1586
#
# 0.050
# 57.4 13.32 15.75 28.46 0.1583
# 54.7 12.75 14.88 25.04 0.1571
# 59.2 13.69 16.17 29.47 0.1591
#
# 0.100
# 60.4 12.77 17.76 29.59 0.1595
# 57.1 12.21 16.68 25.81 0.1579
# 62.8 13.18 18.29 30.37 0.1608
#
# 0.150
# 66.2 12.67 20.40 30.42 0.1622
# 61.3 12.02 18.98 26.83 0.1593
# 69.5 13.10 21.11 31.73 0.1642
#
# 0.200
# 74.7 12.93 23.71 31.58 0.1663
# 65.6 12.11 21.74 25.40 0.1611
# 79.8 13.47 24.63 33.22 0.1698
#
# 0.250
# 87.9 13.73 27.30 32.85 0.1744
# 74.8 12.56 24.48 27.96 0.1652
# 93.3 14.36 28.58 34.32 0.1782
#
# 0.300
# 98.8 15.12 30.68 32.55 0.1806
# 77.6 13.56 26.80 22.78 0.1668
# 108.4 15.90 32.27 34.47 0.1884
#
# 0.350
# 109.5 17.20 32.61 31.43 0.1875
# 87.3 15.05 27.19 25.03 0.1714
# 122.5 18.36 34.85 33.43 0.1988
#
# 0.400
# 119.0 20.40 33.21 28.66 0.1945
# 98.6 17.21 26.71 25.75 0.1770
# 134.1 22.08 35.85 31.53 0.2078
#
# 0.450
# 126.4 24.92 32.35 27.05 0.1995
# 98.6 20.18 25.47 21.96 0.1771
# 142.8 27.47 35.44 29.44 0.2148
#
# 0.500
# 129.4 30.55 30.48 24.71 0.2024
# 87.0 23.21 21.36 12.73 0.1730
# 149.3 34.21 34.09 27.89 0.2202

# %% [markdown]
# ### PSF test

# %%
psfTest.psfTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2019-10-30
# commit 84f60bd3a7568c26e44aef9222b9f3492568caa1
#
# No normalization data found, using 1.0.
# No normalization data found, using 1.0.
# No normalization data found, using 1.0.
# -500.000
# dx 1.164 0.989
# dy 0.473 0.414
# dz 0.391 0.104
# psfs 0.373 0.168
#
# -450.000
# dx 0.752 0.676
# dy 0.246 0.223
# dz 0.204 0.078
# psfs 0.227 0.108
#
# -400.000
# dx 0.548 0.456
# dy 0.147 0.143
# dz 0.155 0.071
# psfs 0.136 0.064
#
# -350.000
# dx 0.415 0.353
# dy 0.105 0.100
# dz 0.110 0.052
# psfs 0.086 0.042
#
# -300.000
# dx 0.308 0.270
# dy 0.073 0.077
# dz 0.135 0.051
# psfs 0.058 0.028
#
# -250.000
# dx 0.189 0.173
# dy 0.064 0.061
# dz 0.069 0.049
# psfs 0.040 0.019
#
# -200.000
# dx 0.126 0.115
# dy 0.046 0.052
# dz 0.140 0.059
# psfs 0.030 0.014
#
# -150.000
# dx 0.085 0.076
# dy 0.045 0.042
# dz 0.114 0.099
# psfs 0.023 0.012
#
# -100.000
# dx 0.058 0.053
# dy 0.041 0.042
# dz 0.204 0.121
# psfs 0.020 0.010
#
# -50.000
# dx 0.045 0.043
# dy 0.040 0.042
# dz 0.208 0.170
# psfs 0.017 0.010
#
# -0.000
# dx 0.038 0.043
# dy 0.043 0.044
# dz 0.258 0.165
# psfs 0.017 0.009
#
# 50.000
# dx 0.040 0.042
# dy 0.047 0.047
# dz 0.186 0.217
# psfs 0.018 0.009
#
# 100.000
# dx 0.040 0.038
# dy 0.058 0.056
# dz 0.295 0.140
# psfs 0.018 0.011
#
# 150.000
# dx 0.043 0.042
# dy 0.089 0.076
# dz 0.182 0.162
# psfs 0.022 0.012
#
# 200.000
# dx 0.046 0.048
# dy 0.126 0.110
# dz 0.569 0.263
# psfs 0.030 0.015
#
# 250.000
# dx 0.056 0.060
# dy 0.191 0.176
# dz 0.525 0.323
# psfs 0.040 0.018
#
# 300.000
# dx 0.074 0.074
# dy 0.333 0.283
# dz 0.964 0.303
# psfs 0.056 0.024
#
# 350.000
# dx 0.097 0.090
# dy 0.449 0.355
# dz 0.707 0.292
# psfs 0.084 0.035
#
# 400.000
# dx 0.141 0.140
# dy 0.547 0.469
# dz 0.659 0.230
# psfs 0.132 0.056
#
# 450.000
# dx 0.216 0.217
# dy 0.768 0.671
# dz 0.705 0.272
# psfs 0.228 0.094
#
# 500.000
# dx 0.439 0.415
# dy 1.202 0.979
# dz 1.063 0.312
# psfs 0.368 0.143
