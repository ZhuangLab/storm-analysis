# %% [markdown]
# ## Diagnostics for Cramer-Rao bounds calculations

# %% [markdown]
# ### Configure environment

# %%
import os
os.chdir("/home/hbabcock/Data/storm_analysis/sa_diagnostics/cramer_rao")
print(os.getcwd())

# %%
import storm_analysis.diagnostics.cramer_rao.settings as settings
import storm_analysis.diagnostics.cramer_rao.configure as configure
import storm_analysis.diagnostics.cramer_rao.cr_test as crTest
import storm_analysis.diagnostics.cramer_rao.psf_test as psfTest

# %% [markdown]
# ### Configure

# %%
configure.configure()

# %% [markdown]
# ### Cramer-Rao test

# %%
crTest.crTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-08-29
# commit f98386cbc6026fd35adc62fd5a19aac986492cc2
#
# No normalization data found for psf_fft.psf using 1.0.
# No normalization data found for pupilfn.pfn using 1.0.
# No normalization data found for psf.spline using 1.0.
# -0.500
# 128.8 57.75 32.84 31.51 0.2112
# 110.0 60.16 34.08 21.62 0.1883
# 149.3 34.09 34.21 27.89 0.2202
#
# -0.450
# 121.1 53.17 26.07 30.17 0.2055
# 124.2 53.03 27.15 29.31 0.1977
# 142.8 35.44 27.47 29.44 0.2148
#
# -0.400
# 110.7 48.36 20.80 28.90 0.1977
# 118.6 50.17 21.60 29.27 0.1942
# 134.1 35.85 22.08 31.53 0.2078
#
# -0.350
# 98.9 42.21 17.22 28.07 0.1885
# 98.4 44.74 17.84 26.27 0.1803
# 122.5 34.85 18.36 33.43 0.1988
#
# -0.300
# 89.7 35.08 14.89 28.25 0.1820
# 84.7 36.37 15.36 23.38 0.1718
# 108.4 32.27 15.90 34.47 0.1884
#
# -0.250
# 80.4 28.57 13.37 28.58 0.1767
# 82.0 29.22 13.74 26.81 0.1700
# 93.3 28.58 14.36 34.32 0.1782
#
# -0.200
# 71.6 23.21 12.42 27.94 0.1715
# 74.0 23.97 12.75 27.67 0.1659
# 79.8 24.63 13.47 33.22 0.1698
#
# -0.150
# 63.2 19.19 11.94 27.20 0.1671
# 64.4 19.93 12.24 26.10 0.1613
# 69.5 21.11 13.10 31.73 0.1642
#
# -0.100
# 57.8 16.38 11.95 27.03 0.1645
# 58.1 16.92 12.16 23.72 0.1585
# 62.8 18.29 13.18 30.37 0.1608
#
# -0.050
# 54.6 14.42 12.28 26.52 0.1631
# 55.0 14.82 12.47 25.11 0.1572
# 59.2 16.17 13.69 29.47 0.1591
#
# -0.000
# 53.2 13.05 13.06 26.22 0.1624
# 53.5 13.43 13.22 25.62 0.1566
# 58.1 14.66 14.66 29.15 0.1586
#
# 0.050
# 54.6 12.31 14.43 26.66 0.1630
# 54.6 12.59 14.49 25.10 0.1570
# 59.2 13.69 16.17 29.47 0.1591
#
# 0.100
# 57.5 11.90 16.34 26.87 0.1642
# 57.1 12.20 16.44 23.58 0.1582
# 62.8 13.18 18.29 30.37 0.1608
#
# 0.150
# 63.5 11.96 19.17 27.22 0.1675
# 62.8 12.20 19.24 25.86 0.1606
# 69.5 13.10 21.11 31.73 0.1642
#
# 0.200
# 71.5 12.42 23.15 27.92 0.1716
# 72.4 12.59 23.02 27.60 0.1650
# 79.8 13.47 24.63 33.22 0.1698
#
# 0.250
# 80.5 13.38 28.51 28.69 0.1762
# 80.4 13.48 28.00 26.89 0.1693
# 93.3 14.36 28.58 34.32 0.1782
#
# 0.300
# 90.4 14.90 34.92 28.27 0.1836
# 82.9 15.01 34.87 23.44 0.1713
# 108.4 15.90 32.27 34.47 0.1884
#
# 0.350
# 100.4 17.40 42.58 28.40 0.1906
# 96.9 17.33 43.18 26.44 0.1799
# 122.5 18.36 34.85 33.43 0.1988
#
# 0.400
# 110.6 20.91 48.47 29.44 0.1968
# 118.2 20.82 49.18 29.41 0.1937
# 134.1 22.08 35.85 31.53 0.2078
#
# 0.450
# 120.0 26.04 53.19 29.81 0.2043
# 123.1 26.03 52.43 29.01 0.1968
# 142.8 27.47 35.44 29.44 0.2148
#
# 0.500
# 129.6 32.92 57.10 31.00 0.2119
# 108.4 32.74 58.96 21.50 0.1875
# 149.3 34.21 34.09 27.89 0.2202

# %% [markdown]
# ### PSF test

# %%
psfTest.psfTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-08-29
# commit f98386cbc6026fd35adc62fd5a19aac986492cc2
#
# No normalization data found for psf_fft.psf using 1.0.
# No normalization data found for pupilfn.pfn using 1.0.
# No normalization data found for psf.spline using 1.0.
# -500.000
# dx 0.104 1.142
# dy 0.127 0.539
# dz 0.228 0.285
# psfs 0.101 0.351
#
# -450.000
# dx 0.168 1.003
# dy 0.113 0.394
# dz 0.084 0.192
# psfs 0.058 0.235
#
# -400.000
# dx 0.109 0.755
# dy 0.064 0.276
# dz 0.095 0.127
# psfs 0.043 0.184
#
# -350.000
# dx 0.147 0.615
# dy 0.064 0.164
# dz 0.062 0.128
# psfs 0.032 0.134
#
# -300.000
# dx 0.094 0.511
# dy 0.062 0.132
# dz 0.092 0.106
# psfs 0.031 0.096
#
# -250.000
# dx 0.085 0.248
# dy 0.044 0.101
# dz 0.106 0.110
# psfs 0.024 0.070
#
# -200.000
# dx 0.054 0.175
# dy 0.035 0.082
# dz 0.110 0.123
# psfs 0.022 0.050
#
# -150.000
# dx 0.071 0.152
# dy 0.038 0.076
# dz 0.102 0.198
# psfs 0.024 0.044
#
# -100.000
# dx 0.039 0.109
# dy 0.031 0.070
# dz 0.175 0.198
# psfs 0.020 0.043
#
# -50.000
# dx 0.051 0.095
# dy 0.039 0.064
# dz 0.155 0.304
# psfs 0.016 0.039
#
# -0.000
# dx 0.033 0.071
# dy 0.031 0.074
# dz 0.296 0.283
# psfs 0.015 0.036
#
# 50.000
# dx 0.052 0.069
# dy 0.035 0.087
# dz 0.153 0.206
# psfs 0.014 0.039
#
# 100.000
# dx 0.035 0.061
# dy 0.029 0.107
# dz 0.222 0.328
# psfs 0.009 0.044
#
# 150.000
# dx 0.027 0.067
# dy 0.035 0.147
# dz 0.226 0.411
# psfs 0.010 0.044
#
# 200.000
# dx 0.029 0.072
# dy 0.048 0.194
# dz 0.334 0.425
# psfs 0.012 0.054
#
# 250.000
# dx 0.042 0.106
# dy 0.125 0.286
# dz 0.482 0.542
# psfs 0.019 0.071
#
# 300.000
# dx 0.032 0.141
# dy 0.098 0.452
# dz 1.057 0.781
# psfs 0.017 0.095
#
# 350.000
# dx 0.045 0.176
# dy 0.147 0.648
# dz 0.537 0.595
# psfs 0.034 0.130
#
# 400.000
# dx 0.047 0.268
# dy 0.156 0.702
# dz 0.774 0.737
# psfs 0.038 0.177
#
# 450.000
# dx 0.117 0.367
# dy 0.157 0.867
# dz 0.499 0.794
# psfs 0.052 0.238
#
# 500.000
# dx 0.139 0.516
# dy 0.203 1.154
# dz 0.740 0.916
# psfs 0.091 0.348
