# %% [markdown]
# ## Diagnostics for Cramer-Rao bounds calculations

# %% [markdown]
# ### Configure environment

# %%
import os
os.chdir("/home/hbabcock/Data/storm_analysis/sa_diagnostics/cramer_rao")
print(os.getcwd())

# %%
import storm_analysis.diagnostics.cramer_rao.settings as settings
import storm_analysis.diagnostics.cramer_rao.configure as configure
import storm_analysis.diagnostics.cramer_rao.cr_test as crTest
import storm_analysis.diagnostics.cramer_rao.psf_test as psfTest

# %% [markdown]
# ### Configure

# %%
configure.configure()

# %% [markdown]
# ### Cramer-Rao test

# %%
crTest.crTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-10-01
# commit 2dabb41ff5a5c1a9b1f0a575c039cf19d2c8e1d8
#
# No normalization data found for psf_fft.psf using 1.0.
# No normalization data found for pupilfn.pfn using 1.0.
# No normalization data found for psf.spline using 1.0.
# -0.500
# 135.3 60.03 34.27 32.20 0.2057
# 100.0 54.56 31.16 19.72 0.1813
# 149.3 34.09 34.21 27.89 0.2202
#
# -0.450
# 125.7 55.06 26.74 31.45 0.2001
# 113.5 48.91 25.09 27.17 0.1892
# 142.8 35.44 27.47 29.44 0.2148
#
# -0.400
# 114.7 49.65 21.21 29.04 0.1915
# 109.9 46.91 20.13 27.49 0.1868
# 134.1 35.85 22.08 31.53 0.2078
#
# -0.350
# 102.0 42.78 17.39 28.59 0.1827
# 92.5 42.26 16.81 25.36 0.1757
# 122.5 34.85 18.36 33.43 0.1988
#
# -0.300
# 92.4 35.40 14.95 29.27 0.1767
# 80.7 34.71 14.62 22.62 0.1690
# 108.4 32.27 15.90 34.47 0.1884
#
# -0.250
# 82.4 28.54 13.34 28.33 0.1708
# 79.5 28.12 13.16 26.29 0.1683
# 93.3 28.58 14.36 34.32 0.1782
#
# -0.200
# 71.8 23.03 12.34 28.33 0.1652
# 72.5 23.13 12.25 26.89 0.1648
# 79.8 24.63 13.47 33.22 0.1698
#
# -0.150
# 63.9 19.10 11.87 27.67 0.1607
# 63.2 19.23 11.79 25.33 0.1606
# 69.5 21.11 13.10 31.73 0.1642
#
# -0.100
# 58.4 16.28 11.82 26.93 0.1588
# 57.2 16.34 11.72 23.08 0.1581
# 62.8 18.29 13.18 30.37 0.1608
#
# -0.050
# 54.5 14.24 12.14 26.68 0.1571
# 54.4 14.34 12.04 24.76 0.1570
# 59.2 16.17 13.69 29.47 0.1591
#
# -0.000
# 53.4 12.93 12.92 26.37 0.1565
# 53.2 13.00 12.78 25.18 0.1564
# 58.1 14.66 14.66 29.15 0.1586
#
# 0.050
# 54.5 12.14 14.24 26.52 0.1570
# 54.1 12.16 14.01 24.57 0.1568
# 59.2 13.69 16.17 29.47 0.1591
#
# 0.100
# 58.2 11.79 16.20 27.26 0.1586
# 56.3 11.75 15.88 22.94 0.1577
# 62.8 13.18 18.29 30.37 0.1608
#
# 0.150
# 63.5 11.83 19.01 27.57 0.1610
# 61.7 11.73 18.55 25.40 0.1599
# 69.5 13.10 21.11 31.73 0.1642
#
# 0.200
# 72.5 12.33 23.01 27.91 0.1653
# 70.8 12.09 22.15 27.09 0.1640
# 79.8 13.47 24.63 33.22 0.1698
#
# 0.250
# 82.9 13.37 28.52 28.62 0.1717
# 77.8 12.91 26.86 26.24 0.1677
# 93.3 14.36 28.58 34.32 0.1782
#
# 0.300
# 92.4 14.97 35.37 29.03 0.1766
# 79.1 14.27 33.24 22.47 0.1684
# 108.4 15.90 32.27 34.47 0.1884
#
# 0.350
# 103.1 17.53 43.08 28.56 0.1840
# 91.1 16.32 40.78 25.26 0.1749
# 122.5 18.36 34.85 33.43 0.1988
#
# 0.400
# 114.6 21.25 49.90 30.27 0.1911
# 109.1 19.42 45.94 27.55 0.1862
# 134.1 22.08 35.85 31.53 0.2078
#
# 0.450
# 126.5 26.73 55.11 30.46 0.2006
# 112.6 24.06 48.45 27.15 0.1889
# 142.8 27.47 35.44 29.44 0.2148
#
# 0.500
# 135.6 34.50 60.17 32.62 0.2069
# 99.0 29.87 53.79 19.72 0.1808
# 149.3 34.21 34.09 27.89 0.2202

# %% [markdown]
# ### PSF test

# %%
psfTest.psfTest()

# %% [markdown]
# ### Reference results

# %% [raw]
# 2018-10-01
# commit 2dabb41ff5a5c1a9b1f0a575c039cf19d2c8e1d8
#
# No normalization data found for psf_fft.psf using 1.0.
# No normalization data found for pupilfn.pfn using 1.0.
# No normalization data found for psf.spline using 1.0.
# -500.000
# dx 0.163 1.204
# dy 0.100 0.534
# dz 0.248 0.264
# psfs 0.057 0.266
#
# -450.000
# dx 0.170 0.884
# dy 0.095 0.361
# dz 0.146 0.225
# psfs 0.051 0.193
#
# -400.000
# dx 0.081 0.668
# dy 0.056 0.279
# dz 0.093 0.101
# psfs 0.036 0.157
#
# -350.000
# dx 0.138 0.642
# dy 0.039 0.206
# dz 0.069 0.079
# psfs 0.020 0.115
#
# -300.000
# dx 0.052 0.482
# dy 0.024 0.145
# dz 0.103 0.094
# psfs 0.013 0.096
#
# -250.000
# dx 0.054 0.266
# dy 0.022 0.105
# dz 0.056 0.090
# psfs 0.010 0.077
#
# -200.000
# dx 0.028 0.176
# dy 0.014 0.076
# dz 0.128 0.104
# psfs 0.007 0.067
#
# -150.000
# dx 0.025 0.142
# dy 0.017 0.070
# dz 0.119 0.161
# psfs 0.006 0.057
#
# -100.000
# dx 0.022 0.110
# dy 0.017 0.066
# dz 0.149 0.157
# psfs 0.007 0.051
#
# -50.000
# dx 0.024 0.085
# dy 0.025 0.062
# dz 0.231 0.188
# psfs 0.006 0.050
#
# -0.000
# dx 0.014 0.074
# dy 0.014 0.069
# dz 0.245 0.239
# psfs 0.006 0.045
#
# 50.000
# dx 0.029 0.070
# dy 0.031 0.087
# dz 0.158 0.184
# psfs 0.007 0.049
#
# 100.000
# dx 0.015 0.069
# dy 0.028 0.111
# dz 0.259 0.360
# psfs 0.012 0.052
#
# 150.000
# dx 0.023 0.074
# dy 0.033 0.136
# dz 0.243 0.318
# psfs 0.017 0.060
#
# 200.000
# dx 0.027 0.079
# dy 0.050 0.191
# dz 0.332 0.761
# psfs 0.025 0.065
#
# 250.000
# dx 0.058 0.106
# dy 0.083 0.275
# dz 0.478 0.607
# psfs 0.041 0.082
#
# 300.000
# dx 0.057 0.127
# dy 0.133 0.408
# dz 0.826 0.657
# psfs 0.051 0.098
#
# 350.000
# dx 0.105 0.203
# dy 0.162 0.572
# dz 0.630 0.673
# psfs 0.068 0.125
#
# 400.000
# dx 0.102 0.253
# dy 0.139 0.673
# dz 0.803 0.651
# psfs 0.087 0.158
#
# 450.000
# dx 0.190 0.365
# dy 0.190 0.871
# dz 0.653 0.771
# psfs 0.100 0.198
#
# 500.000
# dx 0.235 0.551
# dy 0.179 1.092
# dz 1.010 0.949
# psfs 0.101 0.267
